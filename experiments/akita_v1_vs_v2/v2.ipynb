# %%
from optparse import OptionParser
import json
import os
import pickle
import random
import re
import pandas as pd
import pysam
import h5py
import numpy as np

import matplotlib.pyplot as plt
from cooltools.lib.numutils import set_diag
from scipy.stats import spearmanr
# Out:
# /home1/smaruj/miniconda3/envs/basenji_py3.9_tf2.15/lib/python3.9/site-packages/cooltools/lib/numutils.py:652: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def iterative_correction_symmetric(
# /home1/smaruj/miniconda3/envs/basenji_py3.9_tf2.15/lib/python3.9/site-packages/cooltools/lib/numutils.py:727: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def iterative_correction_asymmetric(x, max_iter=1000, tol=1e-5, verbose=False):

# %%
# import tensorrt as trt (if installed, it's not used by Akita anyways)
import tensorflow as tf
from basenji import seqnn, stream, dataset, dna_io
# Out:
# 2024-04-22 13:56:14.662498: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 13:56:14.662572: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 13:56:14.693963: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-22 13:56:14.788741: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 13:56:17.567392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from akita_utils.utils import ut_dense
from akita_utils.dna_utils import dna_1hot

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '-1' ### run on CPU
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %% [markdown]
# ## Cropping functions

# %%
def crop_center(matrix, new_height=448, new_width=448):
    """
    Crop the central part of a matrix to a specified size.
    
    Parameters:
    - matrix: Input 2D numpy array of shape (height, width).
    - new_height: Height of the cropped matrix.
    - new_width: Width of the cropped matrix.
    
    Returns:
    - Cropped 2D numpy array of shape (new_height, new_width).
    """
    # Calculate the starting points for cropping
    start_x = (matrix.shape[1] - new_width) // 2
    start_y = (matrix.shape[0] - new_height) // 2
    
    # Perform the cropping
    cropped_matrix = matrix[start_y:start_y+new_height, start_x:start_x+new_width]
    
    return cropped_matrix


def matrix_to_upper_triangular_vector_excluding_diagonals(matrix, diagonals_to_exclude=2):
    """
    Convert a square matrix to a vector containing only the upper triangular part,
    excluding a specified number of diagonals from the start.
    
    Parameters:
    - matrix: 2D numpy array of shape (N, N)
    - diagonals_to_exclude: Number of diagonals to exclude from the start (default is 2)
    
    Returns:
    - Vector containing the upper triangular part of the matrix, excluding the specified diagonals.
    """
    # Use np.triu_indices to get the indices of the upper triangular part, excluding specified diagonals
    upper_tri_indices = np.triu_indices(matrix.shape[0], diagonals_to_exclude)
    
    # Extract the upper triangular part of the matrix using the indices
    upper_tri_vector = matrix[upper_tri_indices]
    
    return upper_tri_vector


def crop_and_vectorize(vector_prediction):
    maps = ut_dense(vector_prediction[0,:,:])
    cropped_maps = np.array([crop_center(maps[:,:,target_index]) for target_index in range(maps.shape[2])])
    cropped_maps = np.transpose(cropped_maps, (1, 2, 0))
    vectorized = np.array([matrix_to_upper_triangular_vector_excluding_diagonals(cropped_maps[:,:,target_index]) for target_index in range(maps.shape[2])])
    return np.transpose(vectorized, (1, 0))

# %%
### names of targets ###

human_dir = "/project/fudenber_735/tensorflow_models/akita/v2/data/hg38/"

hic_targets = pd.read_csv(human_dir+'/targets.txt',sep='\t')
hic_file_dict_num = dict(zip(hic_targets['index'].values, hic_targets['file'].values) )
hic_file_dict = dict(zip(hic_targets['identifier'].values, hic_targets['file'].values) )
hic_num_to_name_dict = dict(zip(hic_targets['index'].values, hic_targets['identifier'].values) )

# read data parameters
data_stats_file = '%s/statistics.json' % human_dir
with open(data_stats_file) as data_stats_open:
    data_stats = json.load(data_stats_open)
seq_length = data_stats['seq_length']
target_length = data_stats['target_length']
hic_diags =  data_stats['diagonal_offset']
target_crop = data_stats['crop_bp'] // data_stats['pool_width']
target_length1 = data_stats['seq_length'] // data_stats['pool_width']

# %% [markdown]
# ## Reading test dataframe and loading targets

# %%
v1_data_split_path = "/project/fudenber_735/tensorflow_models/akita/v1/data/sequences.bed"

# %%
all_test_V1_seqs = pd.read_csv(v1_data_split_path, sep='\t', names=['chr','start','stop','type'])
all_test_V1_seqs = all_test_V1_seqs.iloc[all_test_V1_seqs['type'].values=='test']

# %%
overlap_test = pd.read_csv("./data/v1_v2_sequences.tsv", sep='\t')

# %%
num_models = overlap_test.type_v2.nunique()

# %%
overlap_test["model"] = overlap_test.apply(lambda x: int(str(x.type_v2)[-1]), axis=1)

# %%
# reading inputs and targets
data_dir_v1 = "/project/fudenber_735/tensorflow_models/akita/v1/data/"
test_data_v1 = dataset.SeqDataset(data_dir_v1, 'test', batch_size=8)
test_inputs, test_targets = test_data_v1.numpy(return_inputs=True, return_outputs=True)

# %%
# calculate the difference in windows' sizes
v1_seq_length = len(test_inputs[0])
v2_seq_length = 1310720
to_expand = (v2_seq_length - v1_seq_length) // 2

# %% [markdown]
# ## General models parameters

# %%
# model's parameters
batch_size=8 
head_index = 0 # human!
shifts = "0"
rc = False

# %%
shifts = [int(shift) for shift in shifts.split(",")]

# %%
models_dir = "/project/fudenber_735/tensorflow_models/akita/v2/models"

# %% [markdown]
# ## iterating over models

# %%
genome_fasta = "/project/fudenber_735/genomes/hg38/hg38.fa"

# open genome FASTA
genome_open = pysam.Fastafile(genome_fasta)

# %%
# from akita_utils.stats_utils import plot_map

# %%
all_cropped_preds = []
all_targets = []
all_dataframes = []

for model_index in range(num_models):
# for model_index in range(1):

    fold_sequences = overlap_test[overlap_test["model"] == model_index]
    
    test_MSE = []
    test_Spearman = []
    
    params_file = models_dir + f"/f{model_index}c0" + "/train" + "/params.json"
    model_file = models_dir + f"/f{model_index}c0" + "/train" + f"/model{head_index}_best.h5"

    # read model parameters
    with open(params_file) as params_open:
        params = json.load(params_open)
    params_train = params["train"]
    params_model = params["model"]
    
    if batch_size is None:
        batch_size = params_train["batch_size"]
    else:
        batch_size = batch_size

    # load model
    seqnn_model = seqnn.SeqNN(params_model)
    seqnn_model.restore(model_file, head_i=head_index)
    seqnn_model.build_ensemble(rc, shifts)
    seq_length = int(params_model["seq_length"])

    print("MODEL: ", model_index)
    print("Number of sequences: ", len(fold_sequences))

    for ind, row in fold_sequences.iterrows():
        chr, seq_start, seq_end = row.chr, row.start, row.stop
        myseq_str = chr+':'+str(seq_start)+'-'+str(seq_end)
        print("\t - ", myseq_str)
        v2_seq_start, v2_seq_end = row.start - to_expand, row.stop + to_expand
        
        # fetching
        seq_1hot = dna_1hot(
                genome_open.fetch(
                    chr, v2_seq_start, v2_seq_end
                ).upper()
            )
        expanded_seq_1hot = np.expand_dims(seq_1hot, 0)
        
        index = np.where((all_test_V1_seqs['chr'].values== chr) *
                             (all_test_V1_seqs['start'].values== int(seq_start))*
                             (all_test_V1_seqs['stop'].values==  int(seq_end)))[0][0]    
        
        test_target = test_targets[index:index+1,:,:]
        test_target = np.squeeze(test_target, axis=0)
        test_pred = seqnn_model.model.predict(expanded_seq_1hot)
        cropped_pred = crop_and_vectorize(test_pred)

        # print("test_target", test_target.shape)
        # print("cropped_pred", cropped_pred.shape)

        # test_target_maps = ut_dense(test_target)
        # test_pred_maps = ut_dense(cropped_pred)
    
        # print("target: ")
        # plot_map(test_target_maps[:,:,0])
        # print("prediction: ")
        # plot_map(test_pred_maps[:,:,0])

        all_targets.append(test_target)
        all_cropped_preds.append(cropped_pred)
        
        MSE = [np.mean((test_target[:,target_index] - cropped_pred[:,target_index]) ** 2) for target_index in range(test_pred.shape[2])]
        test_MSE.append(MSE)
    
        spearman = [spearmanr(cropped_pred[:,target_index], test_target[:,target_index])[0] for target_index in range(test_pred.shape[2])]
        test_Spearman.append(spearman)

    test_MSE_array = np.array(test_MSE)
    test_Spearman_array = np.array(test_Spearman)

    fold_sequences = fold_sequences.copy()
    
    for target_index in range(5):
        fold_sequences.loc[:, f"v2_MSE_{target_index}"] = test_MSE_array[:, target_index]
        fold_sequences.loc[:, f"v2_S_{target_index}"] = test_Spearman_array[:, target_index]
    
    # Now perform your operation
    fold_sequences.loc[:, 'v2_MSE'] = fold_sequences[[f"v2_MSE_{target_index}" for target_index in range(5)]].mean(axis=1)
    fold_sequences.loc[:, 'v2_S'] = fold_sequences[[f"v2_S_{target_index}" for target_index in range(5)]].mean(axis=1)

    all_dataframes.append(fold_sequences)

print("DONE")
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  sequence (InputLayer)       [(None, 1310720, 4)]         0         []
#
#  stochastic_reverse_complem  ((None, 1310720, 4),         0         ['sequence[0][0]']
#  ent (StochasticReverseComp   ())
#  lement)
#
#  stochastic_shift (Stochast  (None, 1310720, 4)           0         ['stochastic_reverse_complemen
#  icShift)                                                           t[0][0]']
#
#  re_lu (ReLU)                (None, 1310720, 4)           0         ['stochastic_shift[0][0]']
#
#  conv1d (Conv1D)             (None, 1310720, 128)         7680      ['re_lu[0][0]']
#
#  batch_normalization (Batch  (None, 1310720, 128)         512       ['conv1d[0][0]']
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 655360, 128)          0         ['batch_normalization[0][0]']
#  D)
#
#  re_lu_1 (ReLU)              (None, 655360, 128)          0         ['max_pooling1d[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 655360, 128)          81920     ['re_lu_1[0][0]']
#
#  batch_normalization_1 (Bat  (None, 655360, 128)          512       ['conv1d_1[0][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 327680, 128)          0         ['batch_normalization_1[0][0]'
#  g1D)                                                               ]
#
#  re_lu_2 (ReLU)              (None, 327680, 128)          0         ['max_pooling1d_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 327680, 128)          81920     ['re_lu_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 327680, 128)          512       ['conv1d_2[0][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 163840, 128)          0         ['batch_normalization_2[0][0]'
#  g1D)                                                               ]
#
#  re_lu_3 (ReLU)              (None, 163840, 128)          0         ['max_pooling1d_2[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 163840, 128)          81920     ['re_lu_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 163840, 128)          512       ['conv1d_3[0][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 81920, 128)           0         ['batch_normalization_3[0][0]'
#  g1D)                                                               ]
#
#  re_lu_4 (ReLU)              (None, 81920, 128)           0         ['max_pooling1d_3[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 81920, 128)           81920     ['re_lu_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 81920, 128)           512       ['conv1d_4[0][0]']
#  chNormalization)
#
#  max_pooling1d_4 (MaxPoolin  (None, 40960, 128)           0         ['batch_normalization_4[0][0]'
#  g1D)                                                               ]
#
#  re_lu_5 (ReLU)              (None, 40960, 128)           0         ['max_pooling1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 40960, 128)           81920     ['re_lu_5[0][0]']
#
#  batch_normalization_5 (Bat  (None, 40960, 128)           512       ['conv1d_5[0][0]']
#  chNormalization)
#
#  max_pooling1d_5 (MaxPoolin  (None, 20480, 128)           0         ['batch_normalization_5[0][0]'
#  g1D)                                                               ]
#
#  re_lu_6 (ReLU)              (None, 20480, 128)           0         ['max_pooling1d_5[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 20480, 128)           81920     ['re_lu_6[0][0]']
#
#  batch_normalization_6 (Bat  (None, 20480, 128)           512       ['conv1d_6[0][0]']
#  chNormalization)
#
#  max_pooling1d_6 (MaxPoolin  (None, 10240, 128)           0         ['batch_normalization_6[0][0]'
#  g1D)                                                               ]
#
#  re_lu_7 (ReLU)              (None, 10240, 128)           0         ['max_pooling1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 10240, 128)           81920     ['re_lu_7[0][0]']
#
#  batch_normalization_7 (Bat  (None, 10240, 128)           512       ['conv1d_7[0][0]']
#  chNormalization)
#
#  max_pooling1d_7 (MaxPoolin  (None, 5120, 128)            0         ['batch_normalization_7[0][0]'
#  g1D)                                                               ]
#
#  re_lu_8 (ReLU)              (None, 5120, 128)            0         ['max_pooling1d_7[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5120, 128)            81920     ['re_lu_8[0][0]']
#
#  batch_normalization_8 (Bat  (None, 5120, 128)            512       ['conv1d_8[0][0]']
#  chNormalization)
#
#  max_pooling1d_8 (MaxPoolin  (None, 2560, 128)            0         ['batch_normalization_8[0][0]'
#  g1D)                                                               ]
#
#  re_lu_9 (ReLU)              (None, 2560, 128)            0         ['max_pooling1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 2560, 128)            81920     ['re_lu_9[0][0]']
#
#  batch_normalization_9 (Bat  (None, 2560, 128)            512       ['conv1d_9[0][0]']
#  chNormalization)
#
#  max_pooling1d_9 (MaxPoolin  (None, 1280, 128)            0         ['batch_normalization_9[0][0]'
#  g1D)                                                               ]
#
#  re_lu_10 (ReLU)             (None, 1280, 128)            0         ['max_pooling1d_9[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 1280, 128)            81920     ['re_lu_10[0][0]']
#
#  batch_normalization_10 (Ba  (None, 1280, 128)            512       ['conv1d_10[0][0]']
#  tchNormalization)
#
#  max_pooling1d_10 (MaxPooli  (None, 640, 128)             0         ['batch_normalization_10[0][0]
#  ng1D)                                                              ']
#
#  re_lu_11 (ReLU)             (None, 640, 128)             0         ['max_pooling1d_10[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 640, 64)              24576     ['re_lu_11[0][0]']
#
#  batch_normalization_11 (Ba  (None, 640, 64)              256       ['conv1d_11[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 640, 64)              0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv1d_12 (Conv1D)          (None, 640, 128)             8192      ['re_lu_12[0][0]']
#
#  batch_normalization_12 (Ba  (None, 640, 128)             512       ['conv1d_12[0][0]']
#  tchNormalization)
#
#  dropout (Dropout)           (None, 640, 128)             0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 640, 128)             0         ['max_pooling1d_10[0][0]',
#                                                                      'dropout[0][0]']
#
#  re_lu_13 (ReLU)             (None, 640, 128)             0         ['add[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 640, 64)              24576     ['re_lu_13[0][0]']
#
#  batch_normalization_13 (Ba  (None, 640, 64)              256       ['conv1d_13[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 640, 64)              0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv1d_14 (Conv1D)          (None, 640, 128)             8192      ['re_lu_14[0][0]']
#
#  batch_normalization_14 (Ba  (None, 640, 128)             512       ['conv1d_14[0][0]']
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 640, 128)             0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 640, 128)             0         ['add[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  re_lu_15 (ReLU)             (None, 640, 128)             0         ['add_1[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 640, 64)              24576     ['re_lu_15[0][0]']
#
#  batch_normalization_15 (Ba  (None, 640, 64)              256       ['conv1d_15[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 640, 64)              0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv1d_16 (Conv1D)          (None, 640, 128)             8192      ['re_lu_16[0][0]']
#
#  batch_normalization_16 (Ba  (None, 640, 128)             512       ['conv1d_16[0][0]']
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 640, 128)             0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 640, 128)             0         ['add_1[0][0]',
#                                                                      'dropout_2[0][0]']
#
#  re_lu_17 (ReLU)             (None, 640, 128)             0         ['add_2[0][0]']
#
#  conv1d_17 (Conv1D)          (None, 640, 64)              24576     ['re_lu_17[0][0]']
#
#  batch_normalization_17 (Ba  (None, 640, 64)              256       ['conv1d_17[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 640, 64)              0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv1d_18 (Conv1D)          (None, 640, 128)             8192      ['re_lu_18[0][0]']
#
#  batch_normalization_18 (Ba  (None, 640, 128)             512       ['conv1d_18[0][0]']
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 640, 128)             0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 640, 128)             0         ['add_2[0][0]',
#                                                                      'dropout_3[0][0]']
#
#  re_lu_19 (ReLU)             (None, 640, 128)             0         ['add_3[0][0]']
#
#  conv1d_19 (Conv1D)          (None, 640, 64)              24576     ['re_lu_19[0][0]']
#
#  batch_normalization_19 (Ba  (None, 640, 64)              256       ['conv1d_19[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 640, 64)              0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv1d_20 (Conv1D)          (None, 640, 128)             8192      ['re_lu_20[0][0]']
#
#  batch_normalization_20 (Ba  (None, 640, 128)             512       ['conv1d_20[0][0]']
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 640, 128)             0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 640, 128)             0         ['add_3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  re_lu_21 (ReLU)             (None, 640, 128)             0         ['add_4[0][0]']
#
#  conv1d_21 (Conv1D)          (None, 640, 64)              24576     ['re_lu_21[0][0]']
#
#  batch_normalization_21 (Ba  (None, 640, 64)              256       ['conv1d_21[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 640, 64)              0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv1d_22 (Conv1D)          (None, 640, 128)             8192      ['re_lu_22[0][0]']
#
#  batch_normalization_22 (Ba  (None, 640, 128)             512       ['conv1d_22[0][0]']
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 640, 128)             0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  add_5 (Add)                 (None, 640, 128)             0         ['add_4[0][0]',
#                                                                      'dropout_5[0][0]']
#
#  re_lu_23 (ReLU)             (None, 640, 128)             0         ['add_5[0][0]']
#
#  conv1d_23 (Conv1D)          (None, 640, 64)              24576     ['re_lu_23[0][0]']
#
#  batch_normalization_23 (Ba  (None, 640, 64)              256       ['conv1d_23[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 640, 64)              0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv1d_24 (Conv1D)          (None, 640, 128)             8192      ['re_lu_24[0][0]']
#
#  batch_normalization_24 (Ba  (None, 640, 128)             512       ['conv1d_24[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 640, 128)             0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 640, 128)             0         ['add_5[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  re_lu_25 (ReLU)             (None, 640, 128)             0         ['add_6[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 640, 64)              24576     ['re_lu_25[0][0]']
#
#  batch_normalization_25 (Ba  (None, 640, 64)              256       ['conv1d_25[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 640, 64)              0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv1d_26 (Conv1D)          (None, 640, 128)             8192      ['re_lu_26[0][0]']
#
#  batch_normalization_26 (Ba  (None, 640, 128)             512       ['conv1d_26[0][0]']
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 640, 128)             0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 640, 128)             0         ['add_6[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  re_lu_27 (ReLU)             (None, 640, 128)             0         ['add_7[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 640, 64)              24576     ['re_lu_27[0][0]']
#
#  batch_normalization_27 (Ba  (None, 640, 64)              256       ['conv1d_27[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 640, 64)              0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv1d_28 (Conv1D)          (None, 640, 128)             8192      ['re_lu_28[0][0]']
#
#  batch_normalization_28 (Ba  (None, 640, 128)             512       ['conv1d_28[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 640, 128)             0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 640, 128)             0         ['add_7[0][0]',
#                                                                      'dropout_8[0][0]']
#
#  re_lu_29 (ReLU)             (None, 640, 128)             0         ['add_8[0][0]']
#
#  conv1d_29 (Conv1D)          (None, 640, 64)              24576     ['re_lu_29[0][0]']
#
#  batch_normalization_29 (Ba  (None, 640, 64)              256       ['conv1d_29[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 640, 64)              0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv1d_30 (Conv1D)          (None, 640, 128)             8192      ['re_lu_30[0][0]']
#
#  batch_normalization_30 (Ba  (None, 640, 128)             512       ['conv1d_30[0][0]']
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 640, 128)             0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  add_9 (Add)                 (None, 640, 128)             0         ['add_8[0][0]',
#                                                                      'dropout_9[0][0]']
#
#  re_lu_31 (ReLU)             (None, 640, 128)             0         ['add_9[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 640, 64)              24576     ['re_lu_31[0][0]']
#
#  batch_normalization_31 (Ba  (None, 640, 64)              256       ['conv1d_31[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 640, 64)              0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv1d_32 (Conv1D)          (None, 640, 128)             8192      ['re_lu_32[0][0]']
#
#  batch_normalization_32 (Ba  (None, 640, 128)             512       ['conv1d_32[0][0]']
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 640, 128)             0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 640, 128)             0         ['add_9[0][0]',
#                                                                      'dropout_10[0][0]']
#
#  re_lu_33 (ReLU)             (None, 640, 128)             0         ['add_10[0][0]']
#
#  conv1d_33 (Conv1D)          (None, 640, 80)              51200     ['re_lu_33[0][0]']
#
#  batch_normalization_33 (Ba  (None, 640, 80)              320       ['conv1d_33[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 640, 80)              0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  one_to_two (OneToTwo)       (None, 640, 640, 80)         0         ['re_lu_34[0][0]']
#
#  re_lu_35 (ReLU)             (None, 640, 640, 80)         0         ['one_to_two[0][0]']
#
#  conv2d (Conv2D)             (None, 640, 640, 80)         57600     ['re_lu_35[0][0]']
#
#  batch_normalization_34 (Ba  (None, 640, 640, 80)         320       ['conv2d[0][0]']
#  tchNormalization)
#
#  symmetrize2d (Symmetrize2D  (None, 640, 640, 80)         0         ['batch_normalization_34[0][0]
#  )                                                                  ']
#
#  re_lu_36 (ReLU)             (None, 640, 640, 80)         0         ['symmetrize2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 640, 640, 40)         28800     ['re_lu_36[0][0]']
#
#  batch_normalization_35 (Ba  (None, 640, 640, 40)         160       ['conv2d_1[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 640, 640, 40)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_2 (Conv2D)           (None, 640, 640, 80)         3200      ['re_lu_37[0][0]']
#
#  batch_normalization_36 (Ba  (None, 640, 640, 80)         320       ['conv2d_2[0][0]']
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 640, 640, 80)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  add_11 (Add)                (None, 640, 640, 80)         0         ['symmetrize2d[0][0]',
#                                                                      'dropout_11[0][0]']
#
#  symmetrize2d_1 (Symmetrize  (None, 640, 640, 80)         0         ['add_11[0][0]']
#  2D)
#
#  re_lu_38 (ReLU)             (None, 640, 640, 80)         0         ['symmetrize2d_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 640, 640, 40)         28800     ['re_lu_38[0][0]']
#
#  batch_normalization_37 (Ba  (None, 640, 640, 40)         160       ['conv2d_3[0][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 640, 640, 40)         0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_4 (Conv2D)           (None, 640, 640, 80)         3200      ['re_lu_39[0][0]']
#
#  batch_normalization_38 (Ba  (None, 640, 640, 80)         320       ['conv2d_4[0][0]']
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 640, 640, 80)         0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 640, 640, 80)         0         ['symmetrize2d_1[0][0]',
#                                                                      'dropout_12[0][0]']
#
#  symmetrize2d_2 (Symmetrize  (None, 640, 640, 80)         0         ['add_12[0][0]']
#  2D)
#
#  re_lu_40 (ReLU)             (None, 640, 640, 80)         0         ['symmetrize2d_2[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 640, 640, 40)         28800     ['re_lu_40[0][0]']
#
#  batch_normalization_39 (Ba  (None, 640, 640, 40)         160       ['conv2d_5[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 640, 640, 40)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_6 (Conv2D)           (None, 640, 640, 80)         3200      ['re_lu_41[0][0]']
#
#  batch_normalization_40 (Ba  (None, 640, 640, 80)         320       ['conv2d_6[0][0]']
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 640, 640, 80)         0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  add_13 (Add)                (None, 640, 640, 80)         0         ['symmetrize2d_2[0][0]',
#                                                                      'dropout_13[0][0]']
#
#  symmetrize2d_3 (Symmetrize  (None, 640, 640, 80)         0         ['add_13[0][0]']
#  2D)
#
#  re_lu_42 (ReLU)             (None, 640, 640, 80)         0         ['symmetrize2d_3[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 640, 640, 40)         28800     ['re_lu_42[0][0]']
#
#  batch_normalization_41 (Ba  (None, 640, 640, 40)         160       ['conv2d_7[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 640, 640, 40)         0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 640, 640, 80)         3200      ['re_lu_43[0][0]']
#
#  batch_normalization_42 (Ba  (None, 640, 640, 80)         320       ['conv2d_8[0][0]']
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 640, 640, 80)         0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 640, 640, 80)         0         ['symmetrize2d_3[0][0]',
#                                                                      'dropout_14[0][0]']
#
#  symmetrize2d_4 (Symmetrize  (None, 640, 640, 80)         0         ['add_14[0][0]']
#  2D)
#
#  re_lu_44 (ReLU)             (None, 640, 640, 80)         0         ['symmetrize2d_4[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 640, 640, 40)         28800     ['re_lu_44[0][0]']
#
#  batch_normalization_43 (Ba  (None, 640, 640, 40)         160       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 640, 640, 40)         0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 640, 640, 80)         3200      ['re_lu_45[0][0]']
#
#  batch_normalization_44 (Ba  (None, 640, 640, 80)         320       ['conv2d_10[0][0]']
# ...
#                                                                     ]']
#
#  conv2d_95 (Conv2D)          (None, 640, 640, 80)         3200      ['re_lu_382[0][0]']
#
#  batch_normalization_367 (B  (None, 640, 640, 80)         320       ['conv2d_95[0][0]']
#  atchNormalization)
#
#  dropout_131 (Dropout)       (None, 640, 640, 80)         0         ['batch_normalization_367[0][0
#                                                                     ]']
#
#  add_131 (Add)               (None, 640, 640, 80)         0         ['symmetrize2d_50[0][0]',
#                                                                      'dropout_131[0][0]']
#
#  symmetrize2d_51 (Symmetriz  (None, 640, 640, 80)         0         ['add_131[0][0]']
#  e2D)
#
#  re_lu_383 (ReLU)            (None, 640, 640, 80)         0         ['symmetrize2d_51[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 640, 640, 40)         28800     ['re_lu_383[0][0]']
#
#  batch_normalization_368 (B  (None, 640, 640, 40)         160       ['conv2d_96[0][0]']
#  atchNormalization)
#
#  re_lu_384 (ReLU)            (None, 640, 640, 40)         0         ['batch_normalization_368[0][0
#                                                                     ]']
#
#  conv2d_97 (Conv2D)          (None, 640, 640, 80)         3200      ['re_lu_384[0][0]']
#
#  batch_normalization_369 (B  (None, 640, 640, 80)         320       ['conv2d_97[0][0]']
#  atchNormalization)
#
#  dropout_132 (Dropout)       (None, 640, 640, 80)         0         ['batch_normalization_369[0][0
#                                                                     ]']
#
#  add_132 (Add)               (None, 640, 640, 80)         0         ['symmetrize2d_51[0][0]',
#                                                                      'dropout_132[0][0]']
#
#  symmetrize2d_52 (Symmetriz  (None, 640, 640, 80)         0         ['add_132[0][0]']
#  e2D)
#
#  re_lu_385 (ReLU)            (None, 640, 640, 80)         0         ['symmetrize2d_52[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 640, 640, 40)         28800     ['re_lu_385[0][0]']
#
#  batch_normalization_370 (B  (None, 640, 640, 40)         160       ['conv2d_98[0][0]']
#  atchNormalization)
#
#  re_lu_386 (ReLU)            (None, 640, 640, 40)         0         ['batch_normalization_370[0][0
#                                                                     ]']
#
#  conv2d_99 (Conv2D)          (None, 640, 640, 80)         3200      ['re_lu_386[0][0]']
#
#  batch_normalization_371 (B  (None, 640, 640, 80)         320       ['conv2d_99[0][0]']
#  atchNormalization)
#
#  dropout_133 (Dropout)       (None, 640, 640, 80)         0         ['batch_normalization_371[0][0
#                                                                     ]']
#
#  add_133 (Add)               (None, 640, 640, 80)         0         ['symmetrize2d_52[0][0]',
#                                                                      'dropout_133[0][0]']
#
#  symmetrize2d_53 (Symmetriz  (None, 640, 640, 80)         0         ['add_133[0][0]']
#  e2D)
#
#  re_lu_387 (ReLU)            (None, 640, 640, 80)         0         ['symmetrize2d_53[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 640, 640, 40)         28800     ['re_lu_387[0][0]']
#
#  batch_normalization_372 (B  (None, 640, 640, 40)         160       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  re_lu_388 (ReLU)            (None, 640, 640, 40)         0         ['batch_normalization_372[0][0
#                                                                     ]']
#
#  conv2d_101 (Conv2D)         (None, 640, 640, 80)         3200      ['re_lu_388[0][0]']
#
#  batch_normalization_373 (B  (None, 640, 640, 80)         320       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  dropout_134 (Dropout)       (None, 640, 640, 80)         0         ['batch_normalization_373[0][0
#                                                                     ]']
#
#  add_134 (Add)               (None, 640, 640, 80)         0         ['symmetrize2d_53[0][0]',
#                                                                      'dropout_134[0][0]']
#
#  symmetrize2d_54 (Symmetriz  (None, 640, 640, 80)         0         ['add_134[0][0]']
#  e2D)
#
#  re_lu_389 (ReLU)            (None, 640, 640, 80)         0         ['symmetrize2d_54[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 640, 640, 40)         28800     ['re_lu_389[0][0]']
#
#  batch_normalization_374 (B  (None, 640, 640, 40)         160       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  re_lu_390 (ReLU)            (None, 640, 640, 40)         0         ['batch_normalization_374[0][0
#                                                                     ]']
#
#  conv2d_103 (Conv2D)         (None, 640, 640, 80)         3200      ['re_lu_390[0][0]']
#
#  batch_normalization_375 (B  (None, 640, 640, 80)         320       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  dropout_135 (Dropout)       (None, 640, 640, 80)         0         ['batch_normalization_375[0][0
#                                                                     ]']
#
#  add_135 (Add)               (None, 640, 640, 80)         0         ['symmetrize2d_54[0][0]',
#                                                                      'dropout_135[0][0]']
#
#  symmetrize2d_55 (Symmetriz  (None, 640, 640, 80)         0         ['add_135[0][0]']
#  e2D)
#
#  squeeze_excite_7 (SqueezeE  (None, 640, 640, 80)         2010      ['symmetrize2d_55[0][0]']
#  xcite)
#
#  cropping2d_7 (Cropping2D)   (None, 512, 512, 80)         0         ['squeeze_excite_7[0][0]']
#
#  upper_tri_7 (UpperTri)      (None, 130305, 80)           0         ['cropping2d_7[0][0]']
#
#  re_lu_391 (ReLU)            (None, 130305, 80)           0         ['upper_tri_7[0][0]']
#
#  dense_14 (Dense)            (None, 130305, 5)            405       ['re_lu_391[0][0]']
#
#  switch_reverse_triu_14 (Sw  (None, 130305, 5)            0         ['dense_14[0][0]',
#  itchReverseTriu)                                                    'stochastic_reverse_complemen
#                                                                     t_7[0][1]']
#
# ==================================================================================================
# Total params: 1508143 (5.75 MB)
# Trainable params: 1499183 (5.72 MB)
# Non-trainable params: 8960 (35.00 KB)
# __________________________________________________________________________________________________
# None
# model_strides [2048, 2048]
# target_lengths [130305, 130305]
# target_crops [-64833, -64833]
# MODEL:  7
# Number of sequences:  36
# 	 -  chr14:19988480-21037056
# 1/1 [==============================] - 2s 2s/step
# 	 -  chr14:20512768-21561344
# 1/1 [==============================] - 1s 907ms/step
# 	 -  chr14:21037056-22085632
# 1/1 [==============================] - 1s 917ms/step
# 	 -  chr14:21561344-22609920
# 1/1 [==============================] - 1s 923ms/step
# 	 -  chr14:22085632-23134208
# 1/1 [==============================] - 1s 922ms/step
# 	 -  chr14:22609920-23658496
# 1/1 [==============================] - 1s 908ms/step
# 	 -  chr14:23134208-24182784
# 1/1 [==============================] - 1s 918ms/step
# 	 -  chr14:23658496-24707072
# 1/1 [==============================] - 1s 912ms/step
# 	 -  chr14:24182784-25231360
# 1/1 [==============================] - 1s 918ms/step
# 	 -  chr14:24707072-25755648
# 1/1 [==============================] - 1s 920ms/step
# 	 -  chr14:25231360-26279936
# 1/1 [==============================] - 1s 922ms/step
# 	 -  chr14:25755648-26804224
# 1/1 [==============================] - 1s 913ms/step
# 	 -  chr14:26279936-27328512
# 1/1 [==============================] - 1s 924ms/step
# 	 -  chr16:51128320-52176896
# 1/1 [==============================] - 1s 929ms/step
# 	 -  chr16:51652608-52701184
# 1/1 [==============================] - 1s 921ms/step
# 	 -  chr16:52176896-53225472
# 1/1 [==============================] - 1s 924ms/step
# 	 -  chr16:52701184-53749760
# 1/1 [==============================] - 1s 910ms/step
# 	 -  chr16:53225472-54274048
# 1/1 [==============================] - 1s 924ms/step
# 	 -  chr16:53749760-54798336
# 1/1 [==============================] - 1s 909ms/step
# 	 -  chr16:54274048-55322624
# 1/1 [==============================] - 1s 905ms/step
# 	 -  chr16:74430464-75479040
# 1/1 [==============================] - 1s 905ms/step
# 	 -  chr16:74954752-76003328
# 1/1 [==============================] - 1s 923ms/step
# 	 -  chr16:75479040-76527616
# 1/1 [==============================] - 1s 920ms/step
# 	 -  chr16:76003328-77051904
# 1/1 [==============================] - 1s 913ms/step
# 	 -  chr16:76527616-77576192
# 1/1 [==============================] - 1s 912ms/step
# 	 -  chr16:77051904-78100480
# 1/1 [==============================] - 1s 926ms/step
# 	 -  chr17:47593472-48642048
# 1/1 [==============================] - 1s 922ms/step
# 	 -  chr17:48117760-49166336
# 1/1 [==============================] - 1s 914ms/step
# 	 -  chr17:48642048-49690624
# 1/1 [==============================] - 1s 916ms/step
# 	 -  chr17:49166336-50214912
# 1/1 [==============================] - 1s 917ms/step
# 	 -  chr17:49690624-50739200
# 1/1 [==============================] - 1s 923ms/step
# 	 -  chr17:50214912-51263488
# 1/1 [==============================] - 1s 923ms/step
# 	 -  chr17:50739200-51787776
# 1/1 [==============================] - 1s 923ms/step
# 	 -  chr17:51263488-52312064
# 1/1 [==============================] - 1s 908ms/step
# 	 -  chr17:51787776-52836352
# 1/1 [==============================] - 1s 920ms/step
# 	 -  chr17:52312064-53360640
# 1/1 [==============================] - 1s 915ms/step
# DONE

# %% [markdown]
# ## Collecting Results

# %%
result = pd.concat(all_dataframes)

# %%
# result.to_csv("v2_results.tsv", sep="\t", index=False, header=True)

# %%
fig, ax = plt.subplots(figsize=(10, 8))

scatter = ax.scatter(result["v2_MSE"], result["v2_S"], alpha=0.5)

ax.set_xlabel("MSE")
ax.set_ylabel("Spearman R")

# ax.set_title(f"Correlation between boundary SCD and dot SCD; Pearson Correlation = {rounded_pearson_corr}")

# plt.savefig("./plots/boundarySCD_vs_dotSCD.png", bbox_inches="tight")

plt.show()

# %%
all_cropped_preds = np.array(all_cropped_preds)
all_targets = np.array(all_targets)

# %%
from scipy.stats import spearmanr, pearsonr

# %%
pearR = pearsonr(all_cropped_preds.flatten(), all_targets.flatten())

# %%
pearR
# Out:
# PearsonRResult(statistic=0.6550893010111157, pvalue=0.0)

# %%
spearmanR = spearmanr(all_cropped_preds.flatten(), all_targets.flatten())

# %%
spearmanR
# Out:
# SignificanceResult(statistic=0.5941143091002724, pvalue=0.0)

# %%
mse = ((all_targets.flatten() - all_cropped_preds.flatten()) ** 2).mean()

# %%
mse
# Out:
# 0.13087174
