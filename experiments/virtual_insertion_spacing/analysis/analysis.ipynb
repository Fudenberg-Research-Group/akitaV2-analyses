# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy import stats
from cooltools.lib import numutils
# Out:
# /home1/smaruj/miniconda3/envs/basenji_py3.9_tf2.15/lib/python3.9/site-packages/cooltools/lib/numutils.py:652: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def iterative_correction_symmetric(
# /home1/smaruj/miniconda3/envs/basenji_py3.9_tf2.15/lib/python3.9/site-packages/cooltools/lib/numutils.py:727: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# ...

# %%
from akita_utils.format_io import h5_to_df

# %%
import sys
sys.path.insert(0, "/home1/smaruj/akitaX1-analyses/utils/")
from reading_averaging_utils import (read_and_average_virtual_exp, average_stat_over_targets)
from analysis_utils import split_by_percentile_groups
# Out:
# 2024-02-06 08:54:09.824814: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 08:54:09.824863: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-06 08:54:09.825678: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-06 08:54:09.831273: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# stat metric the analysis is based on
stat_of_analysis_interest = "SCD"
data_dir = "/scratch1/smaruj/spacing_exp"

# %%
# RIGHT ORIENTATION

df_m0_p1 = h5_to_df(data_dir+"/model_0_bg0_R_P1.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p1 = average_stat_over_targets(df_m0_p1, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p2 = h5_to_df(data_dir+"/model_0_bg0_R_P2.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p2 = average_stat_over_targets(df_m0_p2, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p3 = h5_to_df(data_dir+"/model_0_bg0_R_P3.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p3 = average_stat_over_targets(df_m0_p3, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_R = pd.concat([df_m0_p1, df_m0_p2, df_m0_p3])

# %%
# LEFT ORIENTATION

df_m0_p1 = h5_to_df(data_dir+"/model_0_bg0_L_P1.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p1 = average_stat_over_targets(df_m0_p1, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p2 = h5_to_df(data_dir+"/model_0_bg0_L_P2.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p2 = average_stat_over_targets(df_m0_p2, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p3 = h5_to_df(data_dir+"/model_0_bg0_L_P3.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p3 = average_stat_over_targets(df_m0_p3, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_L = pd.concat([df_m0_p1, df_m0_p2, df_m0_p3])

# %%
# CONVERGENT ORIENTATION

df_m0_p1 = h5_to_df(data_dir+"/model_0_bg0_C_P1.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p1 = average_stat_over_targets(df_m0_p1, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p2 = h5_to_df(data_dir+"/model_0_bg0_C_P2.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p2 = average_stat_over_targets(df_m0_p2, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p3 = h5_to_df(data_dir+"/model_0_bg0_C_P3.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p3 = average_stat_over_targets(df_m0_p3, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_C = pd.concat([df_m0_p1, df_m0_p2, df_m0_p3])

# %%
# DIVERGENT ORIENTATION

df_m0_p1 = h5_to_df(data_dir+"/model_0_bg0_D_P1.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p1 = average_stat_over_targets(df_m0_p1, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p2 = h5_to_df(data_dir+"/model_0_bg0_D_P2.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p2 = average_stat_over_targets(df_m0_p2, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_m0_p3 = h5_to_df(data_dir+"/model_0_bg0_D_P3.h5", ["SCD", "INS-16", "INS-64"], ignore_keys=["insertion_SCD", "disruption_SCD"], average=False) 
df_m0_tg_p3 = average_stat_over_targets(df_m0_p3, model_index=0, head_index=1, stat=stat_of_analysis_interest)

df_D = pd.concat([df_m0_p1, df_m0_p2, df_m0_p3])

# %%
# right
df_split_SCDins_R = split_by_percentile_groups(df_R, column_to_split="insertion_SCD", num_classes=5, 
                               upper_percentile=100, lower_percentile=0, 
                               category_colname="insSCD_group")

# %%
# left
df_split_SCDins_L = split_by_percentile_groups(df_L, column_to_split="insertion_SCD", num_classes=5, 
                               upper_percentile=100, lower_percentile=0, 
                               category_colname="insSCD_group")

# %%
# convergent
df_split_SCDins_C = split_by_percentile_groups(df_C, column_to_split="insertion_SCD", num_classes=5, 
                               upper_percentile=100, lower_percentile=0, 
                               category_colname="insSCD_group")

# %%
# divergent
df_split_SCDins_D = split_by_percentile_groups(df_D, column_to_split="insertion_SCD", num_classes=5, 
                               upper_percentile=100, lower_percentile=0, 
                               category_colname="insSCD_group")

# %%
spacing_df_R = df_split_SCDins_R.groupby(["insSCD_group", "spacer_bp"]).agg({"SCD_m0": "mean"}).reset_index()
spacing_df_L = df_split_SCDins_L.groupby(["insSCD_group", "spacer_bp"]).agg({"SCD_m0": "mean"}).reset_index()
spacing_df_C = df_split_SCDins_C.groupby(["insSCD_group", "spacer_bp"]).agg({"SCD_m0": "mean"}).reset_index()
spacing_df_D = df_split_SCDins_D.groupby(["insSCD_group", "spacer_bp"]).agg({"SCD_m0": "mean"}).reset_index()

# %%
C_color_dict = {"Group_0": "#9fc2e0",
              "Group_1": "#6da3d0",
              "Group_2":"#3b7fb9", 
              "Group_3":"#2d618e", 
              "Group_4":"#1d3f5c"}

D_color_dict = {"Group_0": "#a8e697",
              "Group_1": "#75b863",
              "Group_2":"#59ad42", 
              "Group_3":"#4e913c", 
              "Group_4":"#366928"}

L_color_dict = {"Group_0": "#edae82",
              "Group_1": "#cf8e61",
              "Group_2":"#d47f44", 
              "Group_3":"#b86932", 
              "Group_4":"#9c501a"}

R_color_dict = {"Group_0": "#e99aed",
              "Group_1": "#da58e0",
              "Group_2":"#b436ba", 
              "Group_3":"#a222a8", 
              "Group_4":"#8a2b8f"}

# %% [markdown]
# ## Raw plots for all orientations

# %%
plt.figure(figsize=(10,8))
x = [2 * spacer + 60 for spacer in spacing_df_R.spacer_bp.unique()]

for group in spacing_df_R.insSCD_group.unique():
    plt.plot(x, spacing_df_R[(spacing_df_R["insSCD_group"] == group)]["SCD_m0"], 
             c=R_color_dict[group])

gr4_patch = mpatches.Patch(color="#8a2b8f", label="high")
gr3_patch = mpatches.Patch(color="#a222a8", label="lower_high")
gr2_patch = mpatches.Patch(color="#b436ba", label="medium")
gr1_patch = mpatches.Patch(color="#da58e0", label="upper_low")
gr0_patch = mpatches.Patch(color="#e99aed", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Right >>")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
plt.figure(figsize=(10,8))
x = [2 * spacer + 60 for spacer in spacing_df_L.spacer_bp.unique()]

for group in spacing_df_L.insSCD_group.unique():
    plt.plot(x, spacing_df_L[(spacing_df_L["insSCD_group"] == group)]["SCD_m0"], 
             c=L_color_dict[group])

gr4_patch = mpatches.Patch(color="#9c501a", label="high")
gr3_patch = mpatches.Patch(color="#b86932", label="lower_high")
gr2_patch = mpatches.Patch(color="#d47f44", label="medium")
gr1_patch = mpatches.Patch(color="#cf8e61", label="upper_low")
gr0_patch = mpatches.Patch(color="#edae82", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Left <<")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
plt.figure(figsize=(10,8))
x = [spacer + 60 for spacer in spacing_df_C.spacer_bp.unique()]

for group in spacing_df_C.insSCD_group.unique():
    plt.plot(x, spacing_df_C[(spacing_df_C["insSCD_group"] == group)]["SCD_m0"], 
             c=C_color_dict[group])

gr4_patch = mpatches.Patch(color="#1d3f5c", label="high")
gr3_patch = mpatches.Patch(color="#2d618e", label="lower_high")
gr2_patch = mpatches.Patch(color="#3b7fb9", label="medium")
gr1_patch = mpatches.Patch(color="#6da3d0", label="upper_low")
gr0_patch = mpatches.Patch(color="#9fc2e0", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Convergent ><")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
plt.figure(figsize=(10,8))
x = [spacer + 60 for spacer in spacing_df_D.spacer_bp.unique()]

for group in spacing_df_D.insSCD_group.unique():
    plt.plot(x, spacing_df_D[(spacing_df_D["insSCD_group"] == group)]["SCD_m0"], 
             c=D_color_dict[group])

gr4_patch = mpatches.Patch(color="#366928", label="high")
gr3_patch = mpatches.Patch(color="#4e913c", label="lower_high")
gr2_patch = mpatches.Patch(color="#59ad42", label="medium")
gr1_patch = mpatches.Patch(color="#75b863", label="upper_low")
gr0_patch = mpatches.Patch(color="#a8e697", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Divergent <>")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %% [markdown]
# ## Smoothed plots for all orientations

# %%
bin_size = 19

# %%
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

# %%
R_insSCDpercentiles_df = df_split_SCDins_R.groupby(["insSCD_group", "spacer_bp"])["SCD_m0"].agg(
    percentile25 = percentile(25), percentile75 = percentile(75)).reset_index()

# %%
L_insSCDpercentiles_df = df_split_SCDins_L.groupby(["insSCD_group", "spacer_bp"])["SCD_m0"].agg(
    percentile25 = percentile(25), percentile75 = percentile(75)).reset_index()

# %%
C_insSCDpercentiles_df = df_split_SCDins_C.groupby(["insSCD_group", "spacer_bp"])["SCD_m0"].agg(
    percentile25 = percentile(25), percentile75 = percentile(75)).reset_index()

# %%
D_insSCDpercentiles_df = df_split_SCDins_D.groupby(["insSCD_group", "spacer_bp"])["SCD_m0"].agg(
    percentile25 = percentile(25), percentile75 = percentile(75)).reset_index()

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_R.spacer_bp.unique()]

for group in spacing_df_R.insSCD_group.unique():
    plt.plot(x, numutils.smooth(spacing_df_R[(spacing_df_R["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=R_color_dict[group])

    R_percentile25_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    R_percentile75_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, R_percentile25_line, 
                    R_percentile75_line, alpha=0.20, color=R_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#8a2b8f", label="high")
gr3_patch = mpatches.Patch(color="#a222a8", label="lower_high")
gr2_patch = mpatches.Patch(color="#b436ba", label="medium")
gr1_patch = mpatches.Patch(color="#da58e0", label="upper_low")
gr0_patch = mpatches.Patch(color="#e99aed", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Right >>")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_L.spacer_bp.unique()]

for group in spacing_df_L.insSCD_group.unique():
    plt.plot(x, numutils.smooth(spacing_df_L[(spacing_df_L["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=L_color_dict[group])

    L_percentile25_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    L_percentile75_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, L_percentile25_line, 
                    L_percentile75_line, alpha=0.20, color=L_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#9c501a", label="high")
gr3_patch = mpatches.Patch(color="#b86932", label="lower_high")
gr2_patch = mpatches.Patch(color="#d47f44", label="medium")
gr1_patch = mpatches.Patch(color="#cf8e61", label="upper_low")
gr0_patch = mpatches.Patch(color="#edae82", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Left <<")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_C.spacer_bp.unique()]

for group in spacing_df_C.insSCD_group.unique():
    plt.plot(x, numutils.smooth(spacing_df_C[(spacing_df_C["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=C_color_dict[group])

    C_percentile25_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    C_percentile75_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, C_percentile25_line, 
                    C_percentile75_line, alpha=0.20, color=C_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#1d3f5c", label="high")
gr3_patch = mpatches.Patch(color="#2d618e", label="lower_high")
gr2_patch = mpatches.Patch(color="#3b7fb9", label="medium")
gr1_patch = mpatches.Patch(color="#6da3d0", label="upper_low")
gr0_patch = mpatches.Patch(color="#9fc2e0", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Convergent ><")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_D.spacer_bp.unique()]

for group in spacing_df_D.insSCD_group.unique():
    plt.plot(x, numutils.smooth(spacing_df_D[(spacing_df_D["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=D_color_dict[group])

    D_percentile25_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    D_percentile75_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, D_percentile25_line, 
                    D_percentile75_line, alpha=0.20, color=D_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#366928", label="high")
gr3_patch = mpatches.Patch(color="#4e913c", label="lower_high")
gr2_patch = mpatches.Patch(color="#59ad42", label="medium")
gr1_patch = mpatches.Patch(color="#75b863", label="upper_low")
gr0_patch = mpatches.Patch(color="#a8e697", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Divergent <>")
plt.xlabel("Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %% [markdown]
# ## With semilog spacer

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_R.spacer_bp.unique()]

for group in spacing_df_R.insSCD_group.unique():
    plt.semilogx(x, numutils.smooth(spacing_df_R[(spacing_df_R["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=R_color_dict[group])

    R_percentile25_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    R_percentile75_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, R_percentile25_line, 
                    R_percentile75_line, alpha=0.20, color=R_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#8a2b8f", label="high")
gr3_patch = mpatches.Patch(color="#a222a8", label="lower_high")
gr2_patch = mpatches.Patch(color="#b436ba", label="medium")
gr1_patch = mpatches.Patch(color="#da58e0", label="upper_low")
gr0_patch = mpatches.Patch(color="#e99aed", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Right >>")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_L.spacer_bp.unique()]

for group in spacing_df_L.insSCD_group.unique():
    plt.semilogx(x, numutils.smooth(spacing_df_L[(spacing_df_L["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=L_color_dict[group])

    L_percentile25_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    L_percentile75_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, L_percentile25_line, 
                    L_percentile75_line, alpha=0.20, color=L_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#9c501a", label="high")
gr3_patch = mpatches.Patch(color="#b86932", label="lower_high")
gr2_patch = mpatches.Patch(color="#d47f44", label="medium")
gr1_patch = mpatches.Patch(color="#cf8e61", label="upper_low")
gr0_patch = mpatches.Patch(color="#edae82", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Left <<")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_C.spacer_bp.unique()]

for group in spacing_df_C.insSCD_group.unique():
    plt.semilogx(x, numutils.smooth(spacing_df_C[(spacing_df_C["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=C_color_dict[group])

    C_percentile25_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    C_percentile75_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, C_percentile25_line, 
                    C_percentile75_line, alpha=0.20, color=C_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#1d3f5c", label="high")
gr3_patch = mpatches.Patch(color="#2d618e", label="lower_high")
gr2_patch = mpatches.Patch(color="#3b7fb9", label="medium")
gr1_patch = mpatches.Patch(color="#6da3d0", label="upper_low")
gr0_patch = mpatches.Patch(color="#9fc2e0", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper left")

plt.title("Convergent ><")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_D.spacer_bp.unique()]

for group in spacing_df_D.insSCD_group.unique():
    plt.semilogx(x, numutils.smooth(spacing_df_D[(spacing_df_D["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=D_color_dict[group])

    D_percentile25_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    D_percentile75_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, D_percentile25_line, 
                    D_percentile75_line, alpha=0.20, color=D_color_dict[group]) 

gr4_patch = mpatches.Patch(color="#366928", label="high")
gr3_patch = mpatches.Patch(color="#4e913c", label="lower_high")
gr2_patch = mpatches.Patch(color="#59ad42", label="medium")
gr1_patch = mpatches.Patch(color="#75b863", label="upper_low")
gr0_patch = mpatches.Patch(color="#a8e697", label="low")
plt.legend(handles=[gr4_patch, gr3_patch, gr2_patch, gr1_patch, gr0_patch], loc="upper right")

plt.title("Divergent <>")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %% [markdown]
# ## Overlaying top classes

# %%
bin_size = 71

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_D.spacer_bp.unique()]

# ['Group_0', 'Group_1', 'Group_2', 'Group_3', 'Group_4']
for group in ["Group_4"]:
    # convergent
    plt.semilogx(x, numutils.smooth(spacing_df_C[(spacing_df_C["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=C_color_dict[group])

    C_percentile25_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    C_percentile75_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, C_percentile25_line, 
                    C_percentile75_line, alpha=0.20, color=C_color_dict[group]) 

    # divergent
    plt.semilogx(x, numutils.smooth(spacing_df_D[(spacing_df_D["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=D_color_dict[group])

    D_percentile25_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    D_percentile75_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, D_percentile25_line, 
                    D_percentile75_line, alpha=0.20, color=D_color_dict[group]) 

    # left 
    plt.semilogx(x, numutils.smooth(spacing_df_L[(spacing_df_L["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=L_color_dict[group])

    L_percentile25_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    L_percentile75_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, L_percentile25_line, 
                    L_percentile75_line, alpha=0.20, color=L_color_dict[group]) 

    # right
    plt.semilogx(x, numutils.smooth(spacing_df_R[(spacing_df_R["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=R_color_dict[group])

    R_percentile25_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    R_percentile75_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, R_percentile25_line, 
                    R_percentile75_line, alpha=0.20, color=R_color_dict[group]) 

C_patch = mpatches.Patch(color="#1d3f5c", label="convergent ><")
D_patch = mpatches.Patch(color="#366928", label="divergent <>")
L_patch = mpatches.Patch(color="#9c501a", label="left <<")
R_patch = mpatches.Patch(color="#8a2b8f", label="right >>")
plt.legend(handles=[C_patch, D_patch, L_patch, R_patch], loc="upper right")

plt.title("top 20 percentiles of with respect to SCD scores")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
x = [2*spacer + 60 for spacer in spacing_df_D.spacer_bp.unique()]

# ['Group_0', 'Group_1', 'Group_2', 'Group_3', 'Group_4']
for group in ["Group_4"]:
    # convergent
    plt.plot(x, numutils.smooth(spacing_df_C[(spacing_df_C["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=C_color_dict[group])

    C_percentile25_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    C_percentile75_line = numutils.smooth(C_insSCDpercentiles_df[C_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, C_percentile25_line, 
                    C_percentile75_line, alpha=0.20, color=C_color_dict[group]) 

    # divergent
    plt.plot(x, numutils.smooth(spacing_df_D[(spacing_df_D["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=D_color_dict[group])

    D_percentile25_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    D_percentile75_line = numutils.smooth(D_insSCDpercentiles_df[D_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, D_percentile25_line, 
                    D_percentile75_line, alpha=0.20, color=D_color_dict[group]) 

    # left 
    plt.plot(x, numutils.smooth(spacing_df_L[(spacing_df_L["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=L_color_dict[group])

    L_percentile25_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    L_percentile75_line = numutils.smooth(L_insSCDpercentiles_df[L_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, L_percentile25_line, 
                    L_percentile75_line, alpha=0.20, color=L_color_dict[group]) 

    # right
    plt.plot(x, numutils.smooth(spacing_df_R[(spacing_df_R["insSCD_group"] == group)]["SCD_m0"], bin_size),
             c=R_color_dict[group])

    R_percentile25_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile25"], bin_size)
    R_percentile75_line = numutils.smooth(R_insSCDpercentiles_df[R_insSCDpercentiles_df["insSCD_group"] == group]["percentile75"], bin_size)

    ax.fill_between(x, R_percentile25_line, 
                    R_percentile75_line, alpha=0.20, color=R_color_dict[group]) 

C_patch = mpatches.Patch(color="#1d3f5c", label="convergent ><")
D_patch = mpatches.Patch(color="#366928", label="divergent <>")
L_patch = mpatches.Patch(color="#9c501a", label="left <<")
R_patch = mpatches.Patch(color="#8a2b8f", label="right >>")
plt.legend(handles=[C_patch, D_patch, L_patch, R_patch], loc="upper right")

plt.title("top 20 percentiles of with respect to SCD scores")
plt.xlabel("Semilog Inter-motif Distance")
plt.ylabel("Insertion SCD")
# Out:
# Text(0, 0.5, 'Insertion SCD')
